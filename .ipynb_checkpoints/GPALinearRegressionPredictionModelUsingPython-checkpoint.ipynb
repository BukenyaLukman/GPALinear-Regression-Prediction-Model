# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
plt.rcParams['figure.figsize'] = (20.0,10.0)

# %%
os.chdir('/home/bukenya/Downloads/DataScience/data')

# %%
os.listdir()
# Out:
# ['headbrain.csv', 'Simple linear regression_gpa.csv']

# %%
data = pd.read_csv('Simple linear regression_gpa.csv')

# %%
data
# Out:
#      SAT   GPA
# 0   1714  2.40
# 1   1664  2.52
# 2   1760  2.54
# 3   1685  2.74
# 4   1693  2.83
# ..   ...   ...
# 79  1936  3.71
# 80  1810  3.71
# 81  1987  3.73
# 82  1962  3.76
# 83  2050  3.81
#
# [84 rows x 2 columns]

# %%
# Colecting the X and Y values
X = data['GPA'].values
Y = data['SAT'].values

# %%
# Mean of X and Y
mean_x = np.mean(X)
mean_y = np.mean(Y)

# Total number of values
m = len(X)
# Using the formula to calculate the b1 and b0
# b1 == m and b0 == c(gradient and  constant c)
numer = 0
denom = 0
for i in range(m):
    numer += (X[i] - mean_x) * (Y[i] - mean_y)
    denom += (X[i] - mean_x) ** 2
b1 = numer / denom
b0 = mean_y - (b1 * mean_x)
## Printing b1 and b0 or m and c
print(b1,b0)
# Out:
# 245.21763914043967 1028.6406860339694

# %%
## plotting values and Regression line
max_x = np.max(X)
min_x = np.min(X)

# calculating line values x and y
x = np.linspace(min_x,max_x,1000)
y = b0 + b1 * x

# plotting line
plt.plot(x,y,color='#58b970',label='Regression Line')
# plotting scatter plot
plt.scatter(X,Y, c='#ef5423', label='Scatter Plot')

plt.xlabel('GPA')
plt.ylabel('SAT')
plt.legend()
plt.show()

# %%
ss_t = 0
ss_r = 0
for i in range(m):
    y_pred = b0 + b1 * X[i]
    ss_t += (Y[i] - mean_y) ** 2
    ss_r += (Y[i] - y_pred) ** 2
r2 =  1 - (ss_r/ss_t)
print(r2)
# Out:
# 0.4060039147967973
